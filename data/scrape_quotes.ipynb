# %% [markdown]
# ## Extract Historical Stock Data from Yahoo Finance (openBB)

# %% [markdown]
# ### Import Libraries

# %%
import sys
import os
from py.fetch_price_history import fetch_price_history_openbb      

import pandas as pd
import logging
from dotenv import load_dotenv

load_dotenv()

from openbb import obb
import polars as pl
obb.user.credentials.fmp_api_key = os.getenv("FMP_API_KEY")
# Out:
# Extensions to add: benzinga@1.4.1, crypto@1.4.1, currency@1.4.1, derivatives@1.4.1, economy@1.4.2, equity@1.4.1, etf@1.4.1, federal_reserve@1.4.3, fixedincome@1.4.3, fmp@1.4.2, fred@1.4.4, index@1.4.1, intrinio@1.4.1, news@1.4.1, oecd@1.1.1, polygon@1.4.1, regulators@1.4.2, sec@1.4.3, tiingo@1.4.1, tradingeconomics@1.4.1, yfinance@1.4.5
#
# Building...

# %% [markdown]
# ### Define Variables

# %%
from pandas.tseries.offsets import BDay
from datetime import datetime, timedelta

# Time Range adjustment
end_date = (datetime.today() - BDay(1)).to_pydatetime()  # Last business day
start_date = end_date - timedelta(days=10*365)  # 10 years of data

# Convert datetime objects to Unix timestamps (seconds since Jan 1, 1970)
start_timestamp = int(start_date.timestamp())
end_timestamp = int(end_date.timestamp())

# Print the date range
days_difference = (end_date - start_date).days
print(f"Date Range: {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")
print(f"Time span: {days_difference} days ({days_difference/365:.2f} years)")
# Out:
# Date Range: 2015-06-07 to 2025-06-04
# Time span: 3650 days (10.00 years)

# %% [markdown]
# ### Stocks

# %%
tickers_file = 'tickers_sp_500.txt'
with open(tickers_file, 'r') as f:
    tickers = [line.strip() for line in f if line.strip()]

# Replace '.' with '-' for Yahoo Finance compatibility
tickers = [t.replace('.', '-') for t in tickers]
tickers = list(dict.fromkeys(tickers))  # Remove duplicates

###########################################################
# DAILY DATA
###########################################################

daily_output = 'daily_stock_quotes.csv'

df_daily, df_daily_failed = fetch_price_history_openbb(
    tickers, 
    start_date, 
    end_date,
    data_file=daily_output,
    interval='1d',                 # options: ['1d', '1w', '1M']
    provider='fmp',                # options: ['fmp', 'yfinance']
    row_threshold_pct=0.05,        # Filter out rows with fewer than 5% of columns containing values
    column_threshold=0.2,          # Filter out columns with less than 20% of values
    validate_recent_data=True,     # Enable recent data validation
    recent_data_percentage=0.2     # Check the last 20% of rows
)

###########################################################
# MONTHLY DATA
###########################################################

monthly_output = 'monthly_stock_quotes.csv'

df = (df_daily.set_index(pd.to_datetime(df_daily.pop('Date')))
      if 'Date' in df_daily.columns else df_daily.copy())
df.index = pd.to_datetime(df.index)              
(df.resample('MS').last()
   .reset_index()
   .to_csv(monthly_output, index=False))
# Out:
# 📂 Reading existing data from: daily_stock_quotes.csv
# 🗓 Existing data: 2015-05-19 to 2025-05-30
# ✅ Found 500 tickers, ❌ Missing 3 tickers
# ⏳ Fetching data using provider: fmp...
# Will fetch 3 missing tickers from 2015-05-19 to 2025-06-04
# Will update existing tickers from 2025-05-31 to 2025-06-04
# Using FMP batch processing for 503 tickers
# Fetching history for 3 missing tickers...
# Processing attempt 1/2
# Fetching batch of 3 tickers...
# Retrieved data for 3 of 3 missing tickers
# Updating 500 existing tickers...
# Processing attempt 1/2
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# ⏳ Round 1 complete with 200 failed tickers
# Waiting 30 seconds before retrying...
# Processing attempt 2/2
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# ❌ Max retries (1) reached. Skipping 200 tickers
# Updated data for 297 tickers
# ⚠️ Column 'GEV' missing 207 values (41.0%) in recent data
# ⚠️ Column 'KKR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KLAC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MCO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MDLZ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MDT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MET' missing 3 values (0.6%) in recent data
# ⚠️ Column 'META' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MGM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MHK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MKC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MKTX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MLM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MMC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MMM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MNST' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MOH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MOS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MPC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MPWR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MRK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MRNA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MSCI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MSFT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MSI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MTB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MTCH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MTD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MU' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NCLH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NDAQ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NDSN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NEE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NEM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NFLX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NKE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NOC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NOW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NRG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NSC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NTAP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NTRS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NUE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NVDA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NVR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NWS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NWSA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NXPI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'O' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ODFL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'OKE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'OMC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ON' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ORCL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ORLY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'OTIS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'OXY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PANW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PARA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PAYC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PAYX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PCAR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PCG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PEG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PEP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PFE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PFG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PGR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PHM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PKG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PLD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PLTR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PNC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PNR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PNW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PODD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'POOL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PPG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PPL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PRU' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PSA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PSX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PTC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PWR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'PYPL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'QCOM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RCL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'REG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'REGN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RJF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RMD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ROK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ROL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ROP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ROST' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RSG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RTX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'RVTY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SBAC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SBUX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SCHW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SHW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SJM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SLB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SMCI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SNA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SNPS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SOLV' missing 206 values (40.8%) in recent data
# ⚠️ Column 'SPG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SPGI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SRE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STLD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STZ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SWK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SWKS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SYF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SYK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SYY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'T' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TAP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TDG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TDY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TECH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TEL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TER' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TFC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TGT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TJX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TKO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TMO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TMUS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TPL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TPR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TRGP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TRMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TROW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TRV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TSCO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TSLA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TSN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TTWO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TXN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TXT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TYL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UAL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UBER' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UDR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UHS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ULTA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UNH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UNP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'UPS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'URI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'USB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'V' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VICI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VLO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VLTO' missing 82 values (16.2%) in recent data
# ⚠️ Column 'VMC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VRSK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VRSN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VRTX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VST' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VTR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VTRS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'VZ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WAB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WAT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WBA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WBD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WDAY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WDC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WEC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WELL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WFC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WMT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WRB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WSM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WST' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WTW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'WYNN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'XEL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'XOM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'XYL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'YUM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ZBH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ZBRA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ZTS' missing 3 values (0.6%) in recent data
# 🔄 Fetching missing recent data for 206 tickers...
# Processing attempt 1/2
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 6 tickers...
# ⏳ Round 1 complete with 200 failed tickers
# Waiting 30 seconds before retrying...
# Processing attempt 2/2
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# ✅ Updated missing recent data for 206 tickers
# ⚠️ Removing 3 columns with < 20.0% data or < 5 values:
#    GEV (298 values, 11.79%), SOLV (299 values, 11.83%), VLTO (423 values, 16.74%)
# 💾 Saved updated data to daily_stock_quotes.csv

# %% [markdown]
# ### Bonds

# %%
tickers_file = 'tickers_bond.txt'
with open(tickers_file, 'r') as f:
    tickers = [line.strip() for line in f if line.strip()]

# Replace '.' with '-' for Yahoo Finance compatibility
tickers = [t.replace('.', '-') for t in tickers]
tickers = list(dict.fromkeys(tickers))  # Remove duplicates

###########################################################
# DAILY DATA
###########################################################

daily_output = 'daily_bond_quotes.csv'

bonds_daily_df, failed_daily = fetch_price_history_openbb(
    tickers, 
    start_date, 
    end_date,
    data_file=daily_output,
    interval='1d',                 # options: ['1d', '1w', '1M']
    provider='fmp',                # options: ['fmp', 'yfinance']
    row_threshold_pct=0.05,        # Filter out rows with fewer than 5% of columns containing values
    column_threshold=0.2,          # Filter out columns with less than 20% of values
    validate_recent_data=True,     # Enable recent data validation
    recent_data_percentage=0.2     # Check the last 20% of rows
)

###########################################################
# MONTHLY DATA
###########################################################

monthly_output = 'monthly_bond_quotes.csv'

bonds_monthly_prices = (bonds_daily_df.set_index(pd.to_datetime(bonds_daily_df.pop('Date')))
      if 'Date' in bonds_daily_df.columns else bonds_daily_df.copy())
bonds_monthly_prices.index = pd.to_datetime(bonds_monthly_prices.index)              
bonds_monthly_prices = (bonds_monthly_prices.resample('MS').last()
   .reset_index()
   .rename(columns={'index': 'Date'}))

# Save to CSV
bonds_monthly_prices.to_csv(monthly_output, index=False)

display(bonds_monthly_prices.head())
# Out:
# 📂 Reading existing data from: daily_bond_quotes.csv
# 🗓 Existing data: 2015-05-19 to 2025-05-30
# ✅ Found 101 tickers, ❌ Missing 46 tickers
# ⏳ Fetching data using provider: fmp...
# Will fetch 46 missing tickers from 2015-05-19 to 2025-06-04
# Will update existing tickers from 2025-05-31 to 2025-06-04
# Using FMP batch processing for 147 tickers
# Fetching history for 46 missing tickers...
# Processing attempt 1/2
# Fetching batch of 46 tickers...
# Retrieved data for 27 of 46 missing tickers
# Updating 101 existing tickers...
# Processing attempt 1/2
# Fetching batch of 100 tickers...
# Fetching batch of 1 tickers...
# Rate limit reached. Identified 1 failed tickers
# ⏳ Round 1 complete with 1 failed tickers
# Waiting 30 seconds before retrying...
# Processing attempt 2/2
# Fetching batch of 1 tickers...
# Updated data for 51 tickers
# ⚠️ Column 'AGIH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'BEMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'BMOIX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'BMOPX' missing 505 values (100.0%) in recent data
# ⚠️ Column 'BYLD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'CEMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'CMF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'CSHP' missing 284 values (56.2%) in recent data
# ⚠️ Column 'EAGG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ELQD' missing 6 values (1.2%) in recent data
# ⚠️ Column 'EMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'EMHY' missing 3 values (0.6%) in recent data
# ⚠️ Column 'EUSB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'FALN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'FIBR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'FLOT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'GBF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'HYGI' missing 1 values (0.2%) in recent data
# ⚠️ Column 'HYGW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'HYXU' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IAGG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBCA' missing 455 values (90.1%) in recent data
# ⚠️ Column 'IBDQ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDU' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBDY' missing 16 values (3.2%) in recent data
# ⚠️ Column 'IBDZ' missing 248 values (49.1%) in recent data
# ⚠️ Column 'IBGA' missing 260 values (51.5%) in recent data
# ⚠️ Column 'IBGB' missing 456 values (90.3%) in recent data
# ⚠️ Column 'IBGL' missing 456 values (90.3%) in recent data
# ⚠️ Column 'IBHJ' missing 16 values (3.2%) in recent data
# ⚠️ Column 'IBIB' missing 74 values (14.7%) in recent data
# ⚠️ Column 'IBIC' missing 74 values (14.7%) in recent data
# ⚠️ Column 'IBID' missing 74 values (14.7%) in recent data
# ⚠️ Column 'IBIE' missing 74 values (14.7%) in recent data
# ⚠️ Column 'IBIF' missing 78 values (15.4%) in recent data
# ⚠️ Column 'IBIG' missing 78 values (15.4%) in recent data
# ⚠️ Column 'IBIH' missing 78 values (15.4%) in recent data
# ⚠️ Column 'IBII' missing 78 values (15.4%) in recent data
# ⚠️ Column 'IBIJ' missing 78 values (15.4%) in recent data
# ⚠️ Column 'IBIK' missing 248 values (49.1%) in recent data
# ⚠️ Column 'IBIL' missing 456 values (90.3%) in recent data
# ⚠️ Column 'IBMR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTJ' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IBTO' missing 20 values (4.0%) in recent data
# ⚠️ Column 'IBTP' missing 260 values (51.5%) in recent data
# ⚠️ Column 'IBTQ' missing 456 values (90.3%) in recent data
# ⚠️ Column 'ICSH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IMTB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ISTB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IUSB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LDRC' missing 365 values (72.3%) in recent data
# ⚠️ Column 'LDRH' missing 365 values (72.3%) in recent data
# ⚠️ Column 'LDRI' missing 364 values (72.1%) in recent data
# ⚠️ Column 'LDRT' missing 364 values (72.1%) in recent data
# ⚠️ Column 'LEMB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQDB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQDH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQDI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQDW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'STIP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SUB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SUSB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'SUSC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TFLO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TIP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TLH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'TLTW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'USHY' missing 3 values (0.6%) in recent data
# 🔄 Fetching missing recent data for 79 tickers...
# Processing attempt 1/2
# Fetching batch of 79 tickers...
# ✅ Updated missing recent data for 78 tickers
# ⚠️ Removing 27 columns with < 20.0% data or < 5 values:
#    BMOPX (1 values, 0.04%), CSHP (221 values, 8.75%), IBCA (50 values, 1.98%), IBDY (489 values, 19.35%), IBDZ (257 values, 10.17%), IBGA (245 values, 9.70%), IBGB (49 values, 1.94%), IBGL (49 values, 1.94%), IBHJ (489 values, 19.35%), IBIB (431 values, 17.06%), ... and 17 more
#    Found 1 columns with fewer than 5 values!
#      - BMOPX: 1 values (0.040%)
# 💾 Saved updated data to daily_bond_quotes.csv
#         Date    AGG  AGIH  AGRH    AGZ  BEMB  BGRN  BMOIX   BYLD   CEMB  ...  \
# 0 2015-05-01  85.03   NaN   NaN  92.41   NaN   NaN   7.83  17.45  32.96  ...
# 1 2015-06-01  84.11   NaN   NaN  92.06   NaN   NaN   7.75  17.23  32.12  ...
# 2 2015-07-01  84.84   NaN   NaN  92.44   NaN   NaN   7.80  17.36  32.32  ...
# 3 2015-08-01  84.55   NaN   NaN  92.57   NaN   NaN   7.79  17.27  31.66  ...
# 4 2015-09-01  85.24   NaN   NaN  93.05   NaN   NaN   7.84  17.21  30.80  ...
#
#      SUB  SUSB  SUSC   TFLO    TIP     TLH    TLT  TLTW  USHY   USIG
# 0  93.31   NaN   NaN  41.86  87.28  105.66  94.83   NaN   NaN  39.68
# 1  93.44   NaN   NaN  41.83  86.39  103.55  90.97   NaN   NaN  39.09
# 2  93.75   NaN   NaN  41.74  86.85  106.14  95.10   NaN   NaN  39.42
# 3  93.52   NaN   NaN  41.72  86.03  105.57  94.44   NaN   NaN  39.02
# 4  93.84   NaN   NaN  41.78  85.58  107.51  96.30   NaN   NaN  39.37
#
# [5 rows x 102 columns]

# %% [markdown]
# ### Benchmarks

# %%
tickers_file = 'tickers_benchmark.txt'
with open(tickers_file, 'r') as f:
    tickers = [line.strip() for line in f if line.strip()]

# Replace '.' with '-' for Yahoo Finance compatibility
tickers = [t.replace('.', '-') for t in tickers]
tickers = list(dict.fromkeys(tickers))  # Remove duplicates

###########################################################
# DAILY DATA
###########################################################

daily_output = 'daily_benchmark_quotes.csv'

df_daily, df_daily_failed = fetch_price_history_openbb(
    tickers, 
    start_date, 
    end_date,
    data_file=daily_output,
    interval='1d',                 # options: ['1d', '1w', '1M']
    provider='fmp',                # options: ['fmp', 'yfinance']
    row_threshold_pct=0.05,        # Filter out rows with fewer than 5% of columns containing values
    column_threshold=0.2,          # Filter out columns with less than 20% of values
    validate_recent_data=True,     # Enable recent data validation
    recent_data_percentage=0.2     # Check the last 20% of rows
)

###########################################################
# MONTHLY DATA
###########################################################

monthly_output = 'monthly_benchmark_quotes.csv'

df = (df_daily.set_index(pd.to_datetime(df_daily.pop('Date')))
      if 'Date' in df_daily.columns else df_daily.copy())
df.index = pd.to_datetime(df.index)              
(df.resample('MS').last()
   .reset_index()
   .to_csv(monthly_output, index=False))
# Out:
# 📂 Reading existing data from: daily_benchmark_quotes.csv
# 🗓 Existing data: 2015-05-19 to 2025-05-30
# ✅ Found 506 tickers, ❌ Missing 0 tickers
# ⏳ Fetching data using provider: fmp...
# Will update existing tickers from 2025-05-31 to 2025-06-04
# Using FMP batch processing for 505 tickers
# Updating 505 existing tickers...
# Processing attempt 1/2
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 100 tickers...
# Rate limit reached. Identified 100 failed tickers
# Fetching batch of 5 tickers...
# Rate limit reached. Identified 5 failed tickers
# ⏳ Round 1 complete with 205 failed tickers
# Waiting 30 seconds before retrying...
# Processing attempt 2/2
# Fetching batch of 100 tickers...
# Fetching batch of 100 tickers...
# Fetching batch of 5 tickers...
# Updated data for 425 tickers
# ⚠️ Column 'ADME' missing 3 values (0.6%) in recent data
# ⚠️ Column 'EUSC' missing 1 values (0.2%) in recent data
# ⚠️ Column 'FFIU' missing 1 values (0.2%) in recent data
# ⚠️ Column 'HYUP' missing 1 values (0.2%) in recent data
# ⚠️ Column 'IEF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IEFA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IEI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IEO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IETC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGBH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGEB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGHG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGRO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGSB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IGV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IMCV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IMTM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'INCO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'INTF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IOO' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IPAC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IPKW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IQLT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ISCF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ITA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ITB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IUS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IUSG' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IUSV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IVLU' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IVOV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IVV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IVW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IWF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IWL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IWP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IXC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IXN' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IXP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IYF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IYH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IYK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'IYW' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JDIV' missing 336 values (66.5%) in recent data
# ⚠️ Column 'JHMD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JMBS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JMOM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JMST' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JMUB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JPIB' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JPME' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JPSE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JQUA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JSMD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'JVAL' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KBWP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KCE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KIE' missing 3 values (0.6%) in recent data
# ⚠️ Column 'KORP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LGOV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LKOR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LMBS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LQDH' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LRGF' missing 3 values (0.6%) in recent data
# ⚠️ Column 'LVHI' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MAGA' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MBSD' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MDYV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MEAR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MFDX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MFEM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MFLX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MFUS' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MGC' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MGK' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MGV' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MLPX' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MMIT' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MMTM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'MTUM' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NACP' missing 3 values (0.6%) in recent data
# ⚠️ Column 'NANR' missing 3 values (0.6%) in recent data
# ⚠️ Column 'ONEO' missing 1 values (0.2%) in recent data
# 🔄 Fetching missing recent data for 85 tickers...
# Processing attempt 1/2
# Fetching batch of 85 tickers...
# ✅ Updated missing recent data for 85 tickers
# 💾 Saved updated data to daily_benchmark_quotes.csv

# %% [markdown]
# ### Treasury Rates

# %%
tickers_file = 'tickers_treasury.txt'
with open(tickers_file, 'r') as f:
    tickers = [line.strip() for line in f if line.strip()]

# Replace '.' with '-' for Yahoo Finance compatibility
tickers = [t.replace('.', '-') for t in tickers]
tickers = list(dict.fromkeys(tickers))  # Remove duplicates

###########################################################
# DAILY DATA
###########################################################

daily_output = 'daily_treasury_rates.csv'

df_daily, df_daily_failed = fetch_price_history_openbb(
    tickers, 
    start_date, 
    end_date,
    data_file=daily_output,
    interval='1d',                 # options: ['1d', '1w', '1M']
    provider='fmp',                # options: ['fmp', 'yfinance']
    row_threshold_pct=0.05,        # Filter out rows with fewer than 5% of columns containing values
    column_threshold=0.2,          # Filter out columns with less than 20% of values
    validate_recent_data=True,     # Enable recent data validation
    recent_data_percentage=0.2     # Check the last 20% of rows
)

###########################################################
# MONTHLY DATA
###########################################################

monthly_output = 'monthly_treasury_rates.csv'

df = (df_daily.set_index(pd.to_datetime(df_daily.pop('Date')))
      if 'Date' in df_daily.columns else df_daily.copy())
df.index = pd.to_datetime(df.index)              
(df.resample('MS').last()
   .reset_index()
   .to_csv(monthly_output, index=False))
# Out:
# 📂 Reading existing data from: daily_treasury_rates.csv
# 🗓 Existing data: 2015-05-19 to 2025-05-30
# ✅ Found 4 tickers, ❌ Missing 0 tickers
# ⏳ Fetching data using provider: fmp...
# Will update existing tickers from 2025-05-31 to 2025-06-04
# Using FMP batch processing for 4 tickers
# Updating 4 existing tickers...
# Processing attempt 1/2
# Fetching batch of 4 tickers...
# Updated data for 4 tickers
# 💾 Saved updated data to daily_treasury_rates.csv

# %% [markdown]
# ### Sectors

# %%
sectors = [
    'XLE',
    'CLF',
    'XLF',
    'GDX'
]
